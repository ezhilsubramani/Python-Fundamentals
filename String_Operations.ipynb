# %%
 #String Concatenation:
 str1=input("Enter Your Name :")
 str2="Hello"
 output=str2+" "+str1
 print(output)
 str3=", welcome to Python programming"
 final_output=output+str3
 print(final_output)
 #String Slicing and Indexing:
 #Print the first character of the string
 print(final_output[0])
 #Print the last character of the string
 print(final_output[-1])
 #Print the first 5 characters of the string
 print(final_output[:6])
 #Print the last 11 characters of the string
 print(final_output[-11::])
 #Print the string in reverse
 print(final_output[::-1])
 #Use slicing and print the word “Python” from the existing string
 print(final_output[-18:-12])
 #String Methods:
 strM ="Python beginner tutorial"
 #Convert the sentence to uppercase
 str_up=strM.upper()
 print(str_up)
 #Convert the sentence to lowercase
 str_low=strM.lower()
 print(str_low)
 #Use Capitalize and return the sentence to the original input form.
 str_cap=strM.capitalize()
 print(str_cap)
 print(strM)
 #Count the total number of occurrences of character ‘t’  in the string
 strM.count("t")
 #Replace all occurrences of “Python” with “Machine Learning”  in the input string
 #strM = “Python beginner tutorial”
 strM=strM.replace("Python","Machine Learning")
 print(strM)
 #Tuples (Creation, Modification and Access)
 t1=(10,20,30)
 t2=(40,50,60)
 #Concatenate the two tuples and store it in “t_combine”
 t_combine=t1+t2
 print(t_combine)
 #Repeat the elements of “t_combine” 3 times
 t_combine*3
 #Access the 3rd element from “t_combine”
 third_element=t_combine[2]
 print(third_element)
 #Access the first three elements from “t_combine”
 fthree_element=t_combine[:3]
 print(fthree_element)
 #Access the last three elements from “t_combine”
 lthree_elements=t_combine[-3:]
 print(lthree_elements)
# Out:
# Enter Your Name :Ezhil
# Hello Ezhil
# Hello Ezhil, welcome to Python programming
# H
# g
# Hello
# programming
# gnimmargorp nohtyP ot emoclew ,lihzE olleH
# Python
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# Python beginner tutorial
# Machine Learning beginner tutorial
# (10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)
